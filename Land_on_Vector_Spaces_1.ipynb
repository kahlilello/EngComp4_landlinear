# %% [markdown]
# <a href="https://colab.research.google.com/github/kahlilello/EngComp4_landlinear/blob/master/Land_on_Vector_Spaces_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Land on Vector Spaces - L Barba
#
# 1 Transform all the vectors

# %% [markdown]
# test
# https://github.com/engineersCode/EngComp4_landlinear

# %%
import numpy as np
from numpy.random import randint

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
from urllib.request import urlretrieve
URL = 'https://go.gwu.edu/engcomp4plot'
urlretrieve(URL, 'plot_helper.py')
# Out:
# ('plot_helper.py', <http.client.HTTPMessage at 0x784767a96e70>)

# %%
import sys
sys.path.append('../scripts/')

from plot_helper import *

# %%
vectors = [(2,2)]
tails = [(-3,-2), (-3, 1), (0,0), (1,-3)]

# %%
# Two list args (vector and tails)

plot_vector(vectors, tails)

# %%
# 1 min excercise - create a new list

vectors1 = [(2,2), (1,1), (3,6), (5,1)]
tails1 = [(-3,-2), (-3, 1), (0,0), (1,-3)]

plot_vector(vectors1, tails1)

# %%
a = np.array((-2, 1))
b = np.array((1,-3))

origin = np.array((0,0))

vectors = [a, b, a+b]
tails = [origin, a, origin]

plot_vector(vectors, tails)

# %%
c = np.array((2,1))
vectors = [c, 2*c]

plot_vector(vectors)

# %%
d = np.array((2,1))

vectors = [d, -2*d]

plot_vector(vectors)

# %%
i = np.array((1,0))
j = np.array((0,1))

vec = 3* i + 2*j

vectors = [i, j, 3*i, 2*j, vec]

plot_vector(vectors)

# %%
#### Linear Combination #### -- adding together two vectors that were each scaled by a number.
# Span - set of all possible linear combinations.

# %%
vectors = []

for _ in range(30):
  m = randint(-10, 10)
  n = randint(-10, 10)
  vectors.append(( m*i + n*j))

plot_vector(vectors)

# %%
vectors = []

for _ in range(30):
  m = randint(-10, 10)
  n = randint(-10, 10)
  vectors.append(( m*a + n*b))

plot_vector(vectors)

# A & B still fills the whole plan with enough vectors

# %%
STOP #34:14
